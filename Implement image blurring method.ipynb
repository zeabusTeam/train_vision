# %% [markdown]
# # Implement image blurring method
#
#
# Problem: implent your smoothing method. Using only arithmetic operators and numpy library

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread("./images/00.png")
img = cv.cvtColor(img, cv.COLOR_RGB2BGR)
rows, cols, ch = img.shape

# %%
plt.imshow(img)

# %% [markdown]
# # Image Blurring

# %% [markdown]
# ## 1. Averaging

# %% [markdown]
# ### OpenCV

# %%
blur = cv.blur(img,(9,9))

# %%
plt.imshow(blur)

# %% [markdown]
# ### Your method

# %%
for r in rows:
    for c in cols:
# write your code here
# Out:
#   File "<ipython-input-39-417670a5be5d>", line 3
#     # write your code here
#                           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Check result

# %%
# print(np.sum(your_result - blur))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-58211825d672> in <module>
# ----> 1 print(np.sum(your_result - blur))
#
# NameError: name 'your_result' is not defined

# %% [markdown]
# Expected: 0

# %% [markdown]
# ## 2. Median

# %% [markdown]
# ### OpenCV

# %%
median = cv.medianBlur(img,9)

# %%
plt.imshow(median)

# %% [markdown]
# ### Your method

# %%
for r in rows:
    for c in cols:
# write your code here
# Out:
#   File "<ipython-input-40-417670a5be5d>", line 3
#     # write your code here
#                           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Check result

# %%
# print(np.sum(your_result - blur))b
