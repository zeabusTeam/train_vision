# %% [markdown]
# # Implement image blurring method
#
#
# Problem: implent your smoothing method. Using only arithmetic operators and numpy library

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread("./images/00.png")
img = cv.cvtColor(img, cv.COLOR_RGB2BGR)
rows, cols, ch = img.shape

# %%
plt.imshow(img)

# %% [markdown]
# # Image Blurring

# %% [markdown]
# ## 1. Averaging

# %% [markdown]
# ### OpenCV

# %%
blur = cv.blur(img,(10,10))

# %%
plt.imshow(blur)

# %% [markdown]
# ### Your method

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

def arr_slice(array,ix,iy,kx,ky):
    return array[ix:kx,iy:ky]

def blur(array,kx,ky):
    result = []
    for x in range(l-kx):
        for y in range(w-ky):
            rp = sum(sum(arr_slice(im,x,y,kx+x,ky+y)/(kx*ky)))
            result.append(rp)
    img = np.reshape(np.array(result,dtype='uint8'),[(w-kx),(l-ky),3])
    return img

# %% [markdown]
# ### Check result

# %%
image = cv2.imread('./images/01.jpeg')
im = np.array(image, dtype='uint8')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
w,l,c = im.shape
plt.imshow(image)

# %%
img = blur(im,9,9)
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(img)

# %% [markdown]
# Expected: 0

# %% [markdown]
# ## 2. Median

# %% [markdown]
# ### OpenCV

# %%
median = cv.medianBlur(img,9)

# %%
plt.imshow(median)

# %% [markdown]
# ### Your method

# %%
import numpy as np 
import cv2
from matplotlib import pyplot as plt 

def arr_slice(array,ix,iy,kx,ky):
    return array[ix:kx,iy:ky]

def median_blur(array,kx,ky):
    result = []
    for x in range(w-kx):
        for y in range(l-ky):
            rp = np.median(arr_slice(im,x,y,kx+x,ky+y)/(kx*ky))
            result.append(rp)
    img = np.reshape(np.array(result,dtype='uint8'),[(w-kx),(l-ky)])
    return img

# %% [markdown]
# ### Check result

# %%
img = cv2.imread('./images/01.jpeg')
im = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
w,l = im.shape
img_out = median_blur(img,13,1)
plt.imshow(img_out,cmap='gray')

# %%
plthist(
